# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import time
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
import UsefulFunctions as uf
from obspy import UTCDateTime
from obspy import Trace
from obspy import Stream
from obspy.clients.fdsn import Client
from obspy.core.inventory.inventory import Inventory
from obspy.signal.filter import envelope, lowpass
from obspy.clients.fdsn.header import FDSNNoDataException
from obspy import read, read_inventory
client = Client("IRIS")

# %%
EV_NAME = 'Chignik'
# Earthquake variables
# eq = uf.Earthquake(f'{uf.DATA_PATH}/AncScenarioGrids/Anc2018.xml')
eq = uf.Earthquake(f'grids/{EV_NAME}.xml')
eq_lat = eq.event['lat']
eq_lon = eq.event['lon']
eq_dep = eq.event['depth']
# Out:
# Start of Parsing for grids/Chignik.xml
#    ~~Detection stats~~
#     Used a maximum azimuthal gap of 300 degrees and minimum station vector angle of 30 km
#     Number of stations needed: 4
#     Detection Time: 23.179174182210843
#     Azimuthal Gap: 163.53885582737644
#     Max Vector Angle: 151.1813480508942
#     Maximum Epicentral Distance: 152.606667799551
# Finished parsing grid.xml for: M8.2, 161 km E of Sand Point, Alaska, , at 2021-07-29T06:15:48 (ID:us6000f02w)

# %%
# ObsPY variables
station_data = {}

or_time = '2021-07-29T06:15:49'
or_time = UTCDateTime(or_time)
starttime = or_time
endtime = or_time + 360

network = 'AK,NP'
stations = 'S15K,S19K,8051,8035'
# stations = stations.split(',')

channel = 'HN?'
location = '*'

# %%
# Download data
st = client.get_waveforms(network=network, station=stations, location='*', channel=channel, starttime=starttime, endtime=endtime)
inv = client.get_stations(network=network, station=stations, location="*", channel=channel, starttime=starttime,
                                         endtime=endtime, level='response')

# %%
# EQ related information
for net in inv:    
    for station in net:
        name = station.code
        lat = station.latitude
        lon = station.longitude
        # Find closest grid point in ShakeMap grid and pga
        subtracted_list = np.hstack((eq.lats - lat, eq.lons - lon))
        nearest_index = np.nanargmin(np.sum(subtracted_list**2, axis=1))
        pga = eq.pga[nearest_index, 0]
        # Calculate epicentral and hypocentral distance, and first-arrival times
        epi_dist = uf.getDistance(eq_lat, eq_lon, lat, lon)
        hypo_dist = (epi_dist**2 + eq_dep**2)**.5
        p_arr = hypo_dist/eq.vel_p
        s_arr = hypo_dist/eq.vel_s
        surf_arr = hypo_dist/eq.vel_surf
        # Save the info into the data dict
        station_data[name] = {'lat': lat,
                              'lon': lon,
                              'epi_dist': epi_dist,
                              'hypo_dist': hypo_dist,
                              'pga': pga,
                              'p_arr': p_arr,
                              's_arr': s_arr,
                              'surf_arr': surf_arr}

# %%
#test cell for printing stuff
print(inv)
print(st)
print(station_data['S15K']['hypo_dist'])
# Out:
# Inventory created at 2023-04-05T01:57:48.738700Z
# 	Created by: IRIS WEB SERVICE: fdsnws-station | version: 1.1.52
# 		    http://service.iris.edu/fdsnws/station/1/query?starttime=2021-07-29...
# 	Sending institution: IRIS-DMC (IRIS-DMC)
# 	Contains:
# 		Networks (2):
# 			AK, NP
# 		Stations (4):
# 			AK.S15K (Chignik Lagoon, AK, USA)
# 			AK.S19K (Old Harbor, AK, USA)
# 			NP.8035 (AK:Kodiak;Chiniak Sch)
# 			NP.8051 (AK:Kodiak Is;USCG AS Hanger 1)
# 		Channels (12):
# 			AK.S15K..HNZ, AK.S15K..HNN, AK.S15K..HNE, AK.S19K..HNZ,
# 			AK.S19K..HNN, AK.S19K..HNE, NP.8035..HNZ, NP.8035..HNN,
# 			NP.8035..HNE, NP.8051..HNZ, NP.8051..HNN, NP.8051..HNE
# 6 Trace(s) in Stream:
# AK.S15K..HNE | 2021-07-29T06:15:49.008400Z - 2021-07-29T06:21:48.998400Z | 100.0 Hz, 36000 samples
# AK.S15K..HNN | 2021-07-29T06:15:49.008400Z - 2021-07-29T06:21:48.998400Z | 100.0 Hz, 36000 samples
# AK.S15K..HNZ | 2021-07-29T06:15:49.008400Z - 2021-07-29T06:21:48.998400Z | 100.0 Hz, 36000 samples
# AK.S19K..HNE | 2021-07-29T06:15:49.008400Z - 2021-07-29T06:21:48.998400Z | 100.0 Hz, 36000 samples
# AK.S19K..HNN | 2021-07-29T06:15:49.008400Z - 2021-07-29T06:21:48.998400Z | 100.0 Hz, 36000 samples
# AK.S19K..HNZ | 2021-07-29T06:15:49.008400Z - 2021-07-29T06:21:48.998400Z | 100.0 Hz, 36000 samples
# 105.55455849519625

# %%
n_tr = len(st)
stringtotext = 'event, stationcode, hypodist, maxacc, vapp'
print('Number of traces:', n_tr)
alpha = 1
lw = 0.75
fs=14
vapp_list = []
st1 = st.copy()
# for i in len(st1):
#     tr = st1[i]
#     sample_rate = tr.stats.sampling_rate
    
    
st1.attach_response(inv)
st1 = st1.remove_response(output='ACC')

fig, ax = plt.subplots(nrows=n_tr // 3, sharex=True, figsize=(8,n_tr))
fig.subplots_adjust(hspace=0)
for i in range(n_tr // 3):
    sample = st1[i*3].stats.channel[0]
    chan = sample + channel[1] + '[EN]'

    code = st1[i*3].stats.station
    net = st1[i*3].stats.network
    distance = station_data[code]['hypo_dist']
    
    tr_e = st1[i*3].detrend('demean')
    tr_n = st1[i*3 + 1].detrend('demean')
    tr_z = st1[i*3 + 2].detrend('demean')
    
    env_e = envelope(tr_e.data)
    env_n = envelope(tr_n.data)
    env_z = envelope(tr_z.data)
    
    h_max_acc = 0
    h_max_ind = 0
    h_max_time = 0
    if np.max(env_e) >= np.max(env_n):
        h_max_ind = np.argmax(env_e)
        h_max_acc = np.max(env_n)
        h_max_time = tr_e.times()[h_max_ind]
    else:
        h_max_ind = np.argmax(env_n)
        h_max_acc = np.max(env_n)
        h_max_time = tr_n.times()[h_max_ind]
        
    # tr_e = st1[i*3]
    # tr_n = st1[i*3 + 1]
    # tr_z = st1[i*3 + 2]
    
    v_app_e = distance/tr_e.times()[1:]
    v_app_n = distance/tr_n.times()[1:]
    v_app_z = distance/tr_z.times()[1:]
    h_max_vapp = distance/h_max_time
    
    ax[i].plot(v_app_e, env_e[1:], c='r', label=tr_e.stats.channel, lw=lw, alpha=alpha)
    ax[i].plot(v_app_n, env_n[1:], c='c', label=tr_n.stats.channel, lw=lw, alpha=alpha)
    # ax[i].plot(v_app_z, env_z[1:], c='k', label=tr_z.stats.channel, lw=lw, alpha=alpha)    
    ax[i].axvline(h_max_vapp, ls='--', lw=2*lw, c='k', label='Max Acceleration')
    ax[i].text(.01, .98, '%s.%s.%s: %.2f km' % (net, code, chan, distance), ha='left', va='top', transform=ax[i].transAxes)
    ax[i].text(.01, .91, r'$V_{app}$ of Max Acceleration: %.1f' % (np.round(h_max_vapp, 1)), ha='left', va='top', transform=ax[i].transAxes)
    ax[i].legend(loc=(0.0, .55), frameon=False, fancybox=False)
    # ax[i].set_title('%s: %.2f km' % (code, distance))
    vapp_list.append(h_max_vapp)
    stringtotext += '\n%s, %s, %.2f, %.2f, %.2f' % (EV_NAME, code, distance, h_max_acc, h_max_vapp)
# plt.xscale('log')
plt.xlim(5, 1.5)
plt.xlabel(r'Velocity $(km/s)$', fontsize=fs)
fig.text(0.03, 0.5, r'Ground Acceleration $(m/s^2)$', va='center', rotation='vertical', fontsize=fs)
fig.text(0.5, 0.9, 'Chignik M8.2', ha='center', fontsize=fs+2)
plt.savefig(f'Plots/{EV_NAME}.pdf')
plt.show()
# Out:
# Number of traces: 6

# %%
print(vapp_list)
print(stringtotext)
# Out:
# [2.2198645319704786, 2.9615948133440515]
# event, stationcode, hypodist, maxacc, vapp
# Chignik, S15K, 105.55, 2.09, 2.22
# Chignik, S19K, 350.15, 0.16, 2.96

# %%
with open(f'Vapps/{EV_NAME}_vapps.txt', 'w') as file:
    file.write(stringtotext)

# %%
fig, ax = plt.subplots(nrows=4, sharex=True, figsize=(8,10))
for i in range(4):
    code = st1[i].stats.station
    distance = station_data[code]['hypo_dist']
    v_app = distance/st1[i].times()[1:]
    ax[i].plot(st1[i].times(), envelope(st[i].data), c='k')
    ax[i].text(0, np.max(st[i].data[1:])-1000, '%s: %.2f km' % (code, distance), va='top')
# Out:
# /home/afozkos/.conda/envs/ShakeMaps/lib/python3.9/site-packages/obspy/signal/filter.py:206: RuntimeWarning: invalid value encountered in sqrt
#   data = (data ** 2 + hilb ** 2) ** 0.5
# /home/afozkos/.conda/envs/ShakeMaps/lib/python3.9/site-packages/obspy/signal/filter.py:206: RuntimeWarning: invalid value encountered in sqrt
#   data = (data ** 2 + hilb ** 2) ** 0.5
# /home/afozkos/.conda/envs/ShakeMaps/lib/python3.9/site-packages/obspy/signal/filter.py:206: RuntimeWarning: invalid value encountered in sqrt
#   data = (data ** 2 + hilb ** 2) ** 0.5
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[37], line 3
#       1 fig, ax = plt.subplots(nrows=4, sharex=True, figsize=(8,10))
#       2 for i in range(4):
# ----> 3     code = st1[i].stats.station
#       4     distance = station_data[code]['hypo_dist']
#       5     v_app = distance/st1[i].times()[1:]
#
# File ~/.conda/envs/ShakeMaps/lib/python3.9/site-packages/obspy/core/stream.py:643, in Stream.__getitem__(self, index)
#     641     return self.__class__(traces=self.traces.__getitem__(index))
#     642 else:
# --> 643     return self.traces.__getitem__(index)
#
# IndexError: list index out of range

# %%
st[0].stats.sampling_rate
# Out:
# 50.0

# %%
len(st)

# %%
plt.figure()
plt.plot(st1[0].times(), envelope(st1[0].data))

# %%
stt = st1.copy()
stt.trim(starttime=starttime+0, endtime=starttime+60)
stt.plot()

# %%
stt = st.copy()
stt.trim(starttime=starttime, endtime=endtime)

for i in range(len(stt)//3):
    plt.figure()
    # st[i].plot()
    code = stt[i*3].stats.station
    net = stt[i*3].stats.network
    # chan = st1[i].stats.channel
    distance = station_data[code]['hypo_dist']
    plt.plot(stt[i*3].times(), stt[i*3].data, c='r', label=stt[i*3].stats.channel)
    plt.plot(stt[i*3+1].times(), stt[i*3+1].data, c='c', label=stt[i*3].stats.channel)
    plt.plot(stt[i*3+2].times(), stt[i*3+2].data, c='k', label=stt[i*3].stats.channel)

    # plt.text(.01, .99, '%s.%s.%s: %.2f km' % (net, code, chan, distance), ha='left', va='top', transform=plt.transAxes)
    plt.legend(loc='upper right')

# %%
st[0*3+1].times())

# %%
st.plot()

# %%
stime = UTCDateTime('2018-11-30T17:29:29.000Z')
st = client.get_waveforms('AK', 'K223', '?', 'BN?', starttime=starttime, endtime=endtime)
# Out:
# 2002-11-03T22:12:41.000000Z ~~~ 2002-11-03T22:12:51.000000Z
# ---------------------------------------------------------------------------
# FDSNNoDataException                       Traceback (most recent call last)
# Cell In[29], line 2
#       1 print(starttime, '~~~', endtime)
# ----> 2 st = client.get_waveforms('AK', 'K223', '?', 'BN*', starttime=starttime, endtime=endtime)
#
# File ~/.conda/envs/ShakeMaps/lib/python3.9/site-packages/obspy/clients/fdsn/client.py:872, in Client.get_waveforms(self, network, station, location, channel, starttime, endtime, quality, minimumlength, longestonly, filename, attach_response, **kwargs)
#     867 url = self._create_url_from_parameters(
#     868     "dataselect", DEFAULT_PARAMETERS['dataselect'], kwargs)
#     870 # Gzip not worth it for MiniSEED and most likely disabled for this
#     871 # route in any case.
# --> 872 data_stream = self._download(url, use_gzip=False)
#     873 data_stream.seek(0, 0)
#     874 if filename:
#
# File ~/.conda/envs/ShakeMaps/lib/python3.9/site-packages/obspy/clients/fdsn/client.py:1486, in Client._download(self, url, return_string, data, use_gzip, content_type)
#    1481     headers['Content-Type'] = content_type
#    1482 code, data = download_url(
#    1483     url, opener=self._url_opener, headers=headers,
#    1484     debug=self.debug, return_string=return_string, data=data,
#    1485     timeout=self.timeout, use_gzip=use_gzip)
# -> 1486 raise_on_error(code, data)
#    1487 return data
#
# File ~/.conda/envs/ShakeMaps/lib/python3.9/site-packages/obspy/clients/fdsn/client.py:1813, in raise_on_error(code, data)
#    1811 # No data.
#    1812 if code == 204:
# -> 1813     raise FDSNNoDataException("No data available for request.",
#    1814                               server_info)
#    1815 elif code == 400:
#    1816     msg = ("Bad request. If you think your request was valid "
#    1817            "please contact the developers.")
#
# FDSNNoDataException: No data available for request.
# HTTP Status code: 204
# Detailed response of server:
